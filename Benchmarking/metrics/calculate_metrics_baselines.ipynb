# %% [markdown]
# # Calculate Baseline Metrics

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Set working directory to '/n/groups/patel/shakson/aiready/'
import os
os.chdir("/home/shaksonisaac/CGM/mambatf/")

#LOAD Datasets
import pandas as pd
import io
from google.cloud import storage

_BUCKET_NAME = "cgmproject2025"

# Download dataset from GCS
client = storage.Client()
bucket = client.bucket(_BUCKET_NAME)
blob = bucket.blob('ai-ready/data/train_finaltimeseries_meal.feather')
data_bytes = blob.download_as_bytes()
train = pd.read_feather(io.BytesIO(data_bytes))


# Download test set:
client = storage.Client()
bucket = client.bucket(_BUCKET_NAME)
blob = bucket.blob('ai-ready/data/test_finaltimeseries_meal.feather')
data_bytes = blob.download_as_bytes()
test = pd.read_feather(io.BytesIO(data_bytes))

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

def smape(y_true, y_pred):
    return 100 * np.mean(
        2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true) + 1e-8)
    )

def quantile_loss(y_true, y_pred, q=0.5):
    return np.mean(np.maximum(q * (y_true - y_pred), (q - 1) * (y_true - y_pred)))

def calculate_metrics(t_grouped, train_df):
    static_vars = train_df[
        [
            "participant_id",
        ]
    ].drop_duplicates()
    t_grouped = t_grouped.merge(static_vars, on="participant_id", how="left")
    metrics_df = (
        t_grouped.groupby("participant_id")
        .apply(
            lambda df: pd.Series(
                {
                    "SMAPE": smape(df["target"], df["prediction"]),
                    "Quantile_Loss": quantile_loss(df["target"], df["prediction"]),
                    "MAE": np.mean(np.abs(df["prediction"] - df["target"])),
                    "RMSE": np.sqrt(np.mean(np.square(df["prediction"] - df["target"]))),
                }
            )
        )
        .reset_index()
    )
    return metrics_df

def get_confidence_intervals(df, metric, confidence=0.95):
    mean = df[metric].mean()
    sem = stats.sem(df[metric])  # Standard Error of the Mean
    margin_of_error = sem * stats.t.ppf((1 + confidence) / 2, len(df) - 1)
    return mean, mean - margin_of_error, mean + margin_of_error

def calculate_metrics_CI(records, train):
    """
    Calculate metrics for each participant in the records DataFrame.
    """
    metrics_df = calculate_metrics(records, train)

    confidence_intervals = {}
    for metric in ["SMAPE", "MAE", "RMSE", "Quantile_Loss"]:
        mean, lower, upper = get_confidence_intervals(metrics_df, metric)
        confidence_intervals[metric] = {
            "mean": mean,
            "lower": lower,
            "upper": upper
        }
    # Convert to DataFrame for better visualization
    confidence_df = pd.DataFrame(confidence_intervals).T.reset_index()
    confidence_df.columns = ["Metric", "Mean", "Lower CI", "Upper CI"]
    return confidence_df

# %%
import gc
def clear_memory():
    gc.collect()
    import torch
    torch.cuda.empty_cache()
clear_memory()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## DeepAR 1 day

# %%
# Load Data
import os
import sys
from scripts.DeepAR288 import create_deepar_dataloaders, train_deepar, save_model_to_gcs, load_model_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_deepar_dataloaders(train, horizon=12, context_length=288, batchsize=32)

model = load_model_from_gcs(bucket_name="cgmproject2025",model_name="DeepAR_12h_288c", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"].median(dim=-1).values #[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_DeepAR_288.csv", index=False)
# Out:
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model from gs://cgmproject2025/models/predictions/DeepAR_12h_288c/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 100])
#           Metric       Mean  Lower CI   Upper CI
# 0          SMAPE   6.344200  6.017456   6.670944
# 1            MAE   8.701461  8.161062   9.241860
# 2           RMSE  10.203391  9.592172  10.814611
# 3  Quantile_Loss   4.350731  4.080531   4.620930
# /tmp/ipykernel_3619/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
# Load Data
import os
import sys
from scripts.DeepAR576 import create_deepar_dataloaders, train_deepar, save_model_to_gcs, load_model_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_deepar_dataloaders(train, horizon=12, context_length=576, batchsize=32)

model = load_model_from_gcs(bucket_name="cgmproject2025",model_name="DeepAR_12h_576c", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"].median(dim=-1).values #[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_DeepAR_576.csv", index=False)
# Out:
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model from gs://cgmproject2025/models/predictions/DeepAR_12h_576c/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 100])
#           Metric      Mean  Lower CI   Upper CI
# 0          SMAPE  6.009979  5.687757   6.332201
# 1            MAE  8.165768  7.658917   8.672618
# 2           RMSE  9.600438  9.030435  10.170441
# 3  Quantile_Loss  4.082884  3.829459   4.336309
# /tmp/ipykernel_3619/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# # LSTM

# %%
# LSTM Day1

# Load Data
import os
import sys
from scripts.LSTM288 import create_tft_dataloaders,  load_lstm_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_tft_dataloaders(train, horizon=12, context_length=288, batchsize=32)

model = load_lstm_from_gcs(bucket_name="cgmproject2025",model_name="LSTM_12h_288c_baseline", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"] #[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_LSTM_288.csv", index=False)
# Out:
# [2025-09-01 14:41:39.587494] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.12 GB | reserved: 0.17 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded LSTM from gs://cgmproject2025/models/predictions/LSTM_12h_288c_baseline/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 1])
#           Metric      Mean  Lower CI  Upper CI
# 0          SMAPE  5.871031  5.553467  6.188596
# 1            MAE  7.849292  7.361520  8.337064
# 2           RMSE  9.344506  8.773986  9.915027
# 3  Quantile_Loss  3.924646  3.680760  4.168532
# /tmp/ipykernel_3619/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
# LSTM Day2

# Load Data
import os
import sys
from scripts.LSTM576 import create_tft_dataloaders,  load_lstm_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_tft_dataloaders(train, horizon=12, context_length=576, batchsize=32)

model = load_lstm_from_gcs(bucket_name="cgmproject2025",model_name="LSTM_12h_576c_baseline", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"] #[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_LSTM_576.csv", index=False)
# Out:
# [GPU] NVIDIA A100-SXM4-40GB  CC=(8, 0), BF16=OK
# [2025-09-01 14:44:07.815872] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.15 GB | reserved: 0.20 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded LSTM from gs://cgmproject2025/models/predictions/LSTM_12h_576c_baseline/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 1])
#           Metric      Mean  Lower CI   Upper CI
# 0          SMAPE  6.260558  5.910810   6.610306
# 1            MAE  8.383797  7.852318   8.915276
# 2           RMSE  9.922264  9.311075  10.533453
# 3  Quantile_Loss  4.191899  3.926159   4.457638
# /tmp/ipykernel_3619/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# # NHITS

# %%
# NHITS Day1

# Load Data
import os
import sys
from scripts.NHITS288 import create_nhits_dataloaders, load_nhits_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_nhits_dataloaders(train, horizon=12, context_length=288, batchsize=32)

model = load_nhits_from_gcs(bucket_name="cgmproject2025",model_name="NHiTS_12h_288c", training_dataset=training)
model.eval()  # Put model in evaluation mode

# Get the parameter count of tft
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters in NHITS model: {total_params}")

# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"][:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_NHITS_288.csv", index=False)
# Out:
# [2025-09-02 01:49:14.363884] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.18 GB | reserved: 0.26 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded N-HiTS from gs://cgmproject2025/models/predictions/NHiTS_12h_288c/
# Total parameters in NHITS model: 3177944
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 3])
#           Metric       Mean   Lower CI   Upper CI
# 0          SMAPE   6.884256   6.474289   7.294224
# 1            MAE   9.375046   8.744450  10.005642
# 2           RMSE  10.993297  10.276489  11.710105
# 3  Quantile_Loss   4.687523   4.372225   5.002821
# /tmp/ipykernel_29789/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
# NHITS Day2

# Load Data
import os
import sys
from scripts.NHITS576 import create_nhits_dataloaders, load_nhits_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_nhits_dataloaders(train, horizon=12, context_length=576, batchsize=32)

model = load_nhits_from_gcs(bucket_name="cgmproject2025",model_name="NHiTS_12h_576c", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"][:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_NHITS_576.csv", index=False)
# Out:
# [GPU] NVIDIA A100-SXM4-40GB  CC=(8, 0), BF16=OK
# [2025-09-01 14:26:12.509360] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.05 GB | reserved: 0.09 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded N-HiTS from gs://cgmproject2025/models/predictions/NHiTS_12h_576c/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 3])
#           Metric       Mean   Lower CI   Upper CI
# 0          SMAPE   7.268738   6.822963   7.714513
# 1            MAE   9.849632   9.179083  10.520181
# 2           RMSE  11.564327  10.806671  12.321982
# 3  Quantile_Loss   4.924816   4.589541   5.260090
# /tmp/ipykernel_3619/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# ## TimeXer

# %%
# 1 day

# Load Data
import os
import sys
from scripts.TimeXer288 import create_tft_dataloaders, load_timexer_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_tft_dataloaders(train, horizon=36, context_length=288, batchsize=32)

model = load_timexer_from_gcs(bucket_name="cgmproject2025",model_name="TimeXer_12h_288c", training_dataset=training)
model.eval()  # Put model in evaluation mode


# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"] #[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/metrics_TimeXer288.csv", index=False)
# Out:
# [2025-09-01 19:03:43.462781] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.05 GB | reserved: 0.08 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded TimeXer from gs://cgmproject2025/models/predictions/TimeXer_12h_288c/
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 36])
#           Metric       Mean   Lower CI   Upper CI
# 0          SMAPE  11.449368  10.933947  11.964789
# 1            MAE  15.942751  15.100522  16.784980
# 2           RMSE  20.142698  19.090166  21.195230
# 3  Quantile_Loss   7.971376   7.550261   8.392490
# /tmp/ipykernel_2714/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# ## Checkpointing Method

# %%
import os, re
from google.cloud import storage

def download_best_ckpt_by_filename(local_dir: str, bucket_name: str, gcs_prefix: str,
                                   run_prefix: str = "tft576-", metric_key: str = "val_loss"):
    """
    Finds the .ckpt with the smallest {metric_key} in its filename under gcs_prefix,
    e.g., 'tft576-epoch=17-val_loss=3.61.ckpt', downloads it, and returns the local path.
    """
    os.makedirs(local_dir, exist_ok=True)
    client = storage.Client()
    bucket = client.bucket(bucket_name)

    blobs = [b for b in bucket.list_blobs(prefix=gcs_prefix)
             if b.name.endswith(".ckpt")
             and "last.ckpt" not in b.name
             and run_prefix in os.path.basename(b.name)
             and f"{metric_key}=" in os.path.basename(b.name)]

    if not blobs:
        raise FileNotFoundError(f"No epoch checkpoints with {metric_key}=... under gs://{bucket_name}/{gcs_prefix}")

    rx = re.compile(rf"{metric_key}=([0-9]+\.[0-9]+)")
    def score(b):
        m = rx.search(os.path.basename(b.name))
        return float(m.group(1)) if m else float("inf")

    best_blob = min(blobs, key=score)
    local_path = os.path.join(local_dir, os.path.basename(best_blob.name))
    best_blob.download_to_filename(local_path)
    print(f"Downloaded best checkpoint: gs://{bucket_name}/{best_blob.name} -> {local_path}")
    return local_path

# %% [markdown]
# # NHITS with checkpoint

# %%
# NHITS older version

# Load Data
import os
import sys
import torch

# Fetch best ckpt from GCS (use your actual bucket/prefix)
BUCKET = "cgmproject2025"
GCS_PREFIX = "checkpoints_nhits_OPT"   # <- change if your run used a different folder
best_ckpt_path = download_best_ckpt_by_filename("checkpoints", BUCKET, GCS_PREFIX,
                                                run_prefix="nhits_opt-", metric_key="val_loss")

#from TFT_pytorch import log_memory, create_tft_dataloaders, TFT_train
from scripts.NHITSopt import create_nhits_dataloaders, NHiTS, load_nhits_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_nhits_dataloaders(train, horizon=12, context_length=120, batchsize=32)

# Load model from the checkpoint
device = "cuda" if torch.cuda.is_available() else "cpu"
model = NHiTS.load_from_checkpoint(best_ckpt_path, map_location=device).to(device)
model.eval()  # Put model in evaluation mode
# Out:
# Downloaded best checkpoint: gs://cgmproject2025/checkpoints_nhits_OPT/nhits_opt-epoch=01-val_loss=5.66.ckpt -> checkpoints/nhits_opt-epoch=01-val_loss=5.66.ckpt
# [GPU] NVIDIA A100-SXM4-40GB  CC=(8, 0), BF16=OK
# [2025-09-02 01:46:14.350096] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.08 GB | reserved: 0.11 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# NHiTS(
#   	"activation":                        ReLU
#   	"backcast_loss_ratio":               0.0
#   	"batch_normalization":               True
#   	"categorical_groups":                {}
#   	"context_length":                    120
#   	"dataset_parameters":                {'time_idx': 'ds', 'target': 'cgm_glucose', 'group_ids': ['participant_id'], 'weight': None, 'max_encoder_length': 120, 'min_encoder_length': 120, 'min_prediction_idx': np.int64(11), 'min_prediction_length': 12, 'max_prediction_length': 12, 'static_categoricals': ['participant_id', 'clinical_site', 'study_group'], 'static_reals': ['age'], 'time_varying_known_categoricals': ['sleep_stage'], 'time_varying_known_reals': ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag'], 'time_varying_unknown_categoricals': None, 'time_varying_unknown_reals': ['cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std'], 'variable_groups': None, 'constant_fill_strategy': None, 'allow_missing_timesteps': False, 'lags': None, 'add_relative_time_idx': False, 'add_target_scales': True, 'add_encoder_length': True, 'target_normalizer': GroupNormalizer(
#   		method='standard',
#   		groups=['participant_id'],
#   		center=True,
#   		scale_by_group=False,
#   		transformation=None,
#   		method_kwargs={}
#   	), 'categorical_encoders': {'__group_id__participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'clinical_site': NaNLabelEncoder(add_nan=False, warn=True), 'study_group': NaNLabelEncoder(add_nan=False, warn=True), 'sleep_stage': NaNLabelEncoder(add_nan=False, warn=True)}, 'scalers': {'age': StandardScaler(), 'encoder_length': StandardScaler(), 'cgm_glucose_center': StandardScaler(), 'cgm_glucose_scale': StandardScaler(), 'ds': StandardScaler(), 'minute_of_day': StandardScaler(), 'tod_sin': StandardScaler(), 'tod_cos': StandardScaler(), 'activity_steps': StandardScaler(), 'calories_value': StandardScaler(), 'heartrate': StandardScaler(), 'oxygen_saturation': StandardScaler(), 'respiration_rate': StandardScaler(), 'stress_level': StandardScaler(), 'predmeal_flag': StandardScaler(), 'cgm_lag_1': StandardScaler(), 'cgm_lag_3': StandardScaler(), 'cgm_lag_6': StandardScaler(), 'cgm_diff_lag_1': StandardScaler(), 'cgm_diff_lag_3': StandardScaler(), 'cgm_diff_lag_6': StandardScaler(), 'cgm_lagdiff_1_3': StandardScaler(), 'cgm_lagdiff_3_6': StandardScaler(), 'cgm_rolling_mean': StandardScaler(), 'cgm_rolling_std': StandardScaler()}, 'randomize_length': None, 'predict_mode': False}
#   	"downsample_frequencies":            [2, 1, 1]
#   	"dropout":                           0.1
#   	"embedding_labels":                  {'participant_id': {'1023': 0, '1024': 1, '1026': 2, '1027': 3, '1028': 4, '1029': 5, '1030': 6, '1031': 7, '1032': 8, '1033': 9, '1034': 10, '1035': 11, '1036': 12, '1037': 13, '1038': 14, '1039': 15, '1040': 16, '1041': 17, '1042': 18, '1044': 19, '1045': 20, '1046': 21, '1047': 22, '1049': 23, '1050': 24, '1051': 25, '1052': 26, '1053': 27, '1054': 28, '1055': 29, '1056': 30, '1057': 31, '1058': 32, '1060': 33, '1061': 34, '1062': 35, '1063
320': 261, '1321': 262, '1322': 263, '1323': 264, '1324': 265, '1325': 266, '1326': 267, '1327': 268, '1328': 269, '1329': 270, '1330': 271, '1331': 272, '1332': 273, '1333': 274, '1334': 275, '1335': 276, '1336': 277, '1337': 278, '1339': 279, '1340': 280, '1341': 281, '1344': 282, '1345': 283, '1346': 284, '1347': 285, '1348': 286, '1349': 287, '1350': 288, '1351': 289, '1352': 290, '1353': 291, '1354': 292, '1355': 293, '1356': 294, '1357': 295, '1359': 296, '1361': 297, '1362': 298, '1363': 299, '1364': 300, '1365': 301, '1366': 302, '1367': 303, '1368': 304, '1372': 305, '1374': 306, '1376': 307, '1377': 308, '1379': 309, '1380': 310, '1381': ...
#   	"embedding_paddings":                []
#   	"embedding_sizes":                   {'participant_id': (741, 65), 'clinical_site': (3, 3), 'study_group': (4, 3), 'sleep_stage': (5, 4)}
#   	"hidden_size":                       512
#   	"initialization":                    lecun_normal
#   	"interpolation_mode":                linear
#   	"learning_rate":                     0.001
#   	"log_gradient_flow":                 False
#   	"log_interval":                      10
#   	"log_val_interval":                  10
#   	"monotone_constraints":              {}
#   	"n_blocks":                          [2, 2, 1]
#   	"n_layers":                          [2, 2, 2]
#   	"naive_level":                       True
#   	"optimizer":                         adam
#   	"optimizer_params":                  None
#   	"output_size":                       3
#   	"output_transformer":                GroupNormalizer(
#   		method='standard',
#   		groups=['participant_id'],
#   		center=True,
#   		scale_by_group=False,
#   		transformation=None,
#   		method_kwargs={}
#   	)
#   	"pooling_mode":                      max
#   	"pooling_sizes":                     [16, 8, 1]
#   	"prediction_length":                 12
#   	"reduce_on_plateau_min_lr":          1e-05
#   	"reduce_on_plateau_patience":        4
#   	"reduce_on_plateau_reduction":       2.0
#   	"shared_weights":                    True
#   	"static_categoricals":               ['participant_id', 'clinical_site', 'study_group']
#   	"static_hidden_size":                512
#   	"static_reals":                      ['age', 'encoder_length', 'cgm_glucose_center', 'cgm_glucose_scale']
#   	"time_varying_categoricals_decoder": ['sleep_stage']
#   	"time_varying_categoricals_encoder": ['sleep_stage']
#   	"time_varying_reals_decoder":        ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag']
#   	"time_varying_reals_encoder":        ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag', 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   	"weight_decay":                      0.01
#   	"x_categoricals":                    ['participant_id', 'clinical_site', 'study_group', 'sleep_stage']
#   	"x_reals":                           ['age', 'encoder_length', 'cgm_glucose_center', 'cgm_glucose_scale', 'ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag', 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   (loss): QuantileLoss(quantiles=[0.1, 0.5, 0.9])
#   (logging_metrics): ModuleList(
#     (0): SMAPE()
#     (1): MAE()
#     (2): RMSE()
#     (3): MAPE()
#     (4): MASE()
#   )
#   (embeddings): MultiEmbedding(
#     (embeddings): ModuleDict(
#       (participant_id): Embedding(741, 65)
#       (clinical_site): Embedding(3, 3)
#       (study_group): Embedding(4, 3)
#       (sleep_stage): Embedding(5, 4)
#     )
#   )
#   (model): NHiTS(
#     (blocks): ModuleList(
#       (0-1): 2 x NHiTSBlock(
#         (pooling_layer): MaxPool1d(kernel_size=16, stride=16, padding=0, dilation=1, ceil_mode=True)
#         (static_encoder): StaticFeaturesEncoder(
#           (encoder): Sequential(
#             (0): Dropout(p=0.5, inplace=False)
#             (1): Linear(in_features=75, out_features=512, bias=True)
#             (2): ReLU()
#           )
#         )
#         (layers): MLP(
#           (layers): Sequential(
#             (0): Linear(in_features=3700, out_features=512, bias=True)
#             (1): ReLU()
#             (2): Dropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): Dropout(p=0.1, inplace=False)
#             (6): Linear(in_features=512, out_features=138, bias=True)
#           )
#         )
#         (basis): IdentityBasis()
#       )
#       (2-3): 2 x NHiTSBlock(
#         (pooling_layer): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=True)
#         (static_encoder): StaticFeaturesEncoder(
#           (encoder): Sequential(
#             (0): Dropout(p=0.5, inplace=False)
#             (1): Linear(in_features=75, out_features=512, bias=True)
#             (2): ReLU()
#           )
#         )
#         (layers): MLP(
#           (layers): Sequential(
#             (0): Linear(in_features=3707, out_features=512, bias=True)
#             (1): ReLU()
#             (2): Dropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): Dropout(p=0.1, inplace=False)
#             (6): Linear(in_features=512, out_features=156, bias=True)
#           )
#         )
#         (basis): IdentityBasis()
#       )
#       (4): NHiTSBlock(
#         (pooling_layer): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=True)
#         (static_encoder): StaticFeaturesEncoder(
#           (encoder): Sequential(
#             (0): Dropout(p=0.5, inplace=False)
#             (1): Linear(in_features=75, out_features=512, bias=True)
#             (2): ReLU()
#           )
#         )
#         (layers): MLP(
#           (layers): Sequential(
#             (0): Linear(in_features=3812, out_features=512, bias=True)
#             (1): ReLU()
#             (2): Dropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): Dropout(p=0.1, inplace=False)
#             (6): Linear(in_features=512, out_features=156, bias=True)
#           )
#         )
#         (basis): IdentityBasis()
#       )
#     )
#   )
# )

# %%
# Get the parameter count of tft
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters in NHITS model: {total_params}")
# Out:
# Total parameters in NHITS model: 6929424

# %%
# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"][:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/NHITS_288_opt.csv", index=False)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 3])
#           Metric       Mean   Lower CI   Upper CI
# 0          SMAPE   7.008861   6.616066   7.401655
# 1            MAE   9.454677   8.873823  10.035531
# 2           RMSE  11.062330  10.407728  11.716932
# 3  Quantile_Loss   4.727339   4.436912   5.017766
# /tmp/ipykernel_29789/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# # NHITS v2

# %%
# NHITS older version

# Load Data
import os
import sys
import torch

# Fetch best ckpt from GCS (use your actual bucket/prefix)
BUCKET = "cgmproject2025"
GCS_PREFIX = "checkpoints_nhits_288v2"   # <- change if your run used a different folder
best_ckpt_path = download_best_ckpt_by_filename("checkpoints", BUCKET, GCS_PREFIX,
                                                run_prefix="nhits_288-", metric_key="val_loss")

#from TFT_pytorch import log_memory, create_tft_dataloaders, TFT_train
from scripts.NHITS288v2 import create_nhits_dataloaders, NHiTS, load_nhits_from_gcs

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_nhits_dataloaders(train, horizon=12, context_length=288, batchsize=32)

# Load model from the checkpoint
device = "cuda" if torch.cuda.is_available() else "cpu"
model = NHiTS.load_from_checkpoint(best_ckpt_path, map_location=device).to(device)
model.eval()  # Put model in evaluation mode
# Out:
# Downloaded best checkpoint: gs://cgmproject2025/checkpoints_nhits_288v2/nhits_288-epoch=01-val_loss=8.53.ckpt -> checkpoints/nhits_288-epoch=01-val_loss=8.53.ckpt
# [2025-09-02 03:29:25.459498] 🚀 Start of Dataloader Creation
# GPU Mem allocated: 0.00 GB | reserved: 0.03 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# NHiTS(
#   	"activation":                        ReLU
#   	"backcast_loss_ratio":               0.0
#   	"batch_normalization":               False
#   	"categorical_groups":                {}
#   	"context_length":                    288
#   	"dataset_parameters":                {'time_idx': 'ds', 'target': 'cgm_glucose', 'group_ids': ['participant_id'], 'weight': None, 'max_encoder_length': 288, 'min_encoder_length': 288, 'min_prediction_idx': np.int64(11), 'min_prediction_length': 12, 'max_prediction_length': 12, 'static_categoricals': ['participant_id', 'clinical_site', 'study_group'], 'static_reals': ['age'], 'time_varying_known_categoricals': ['sleep_stage'], 'time_varying_known_reals': ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag'], 'time_varying_unknown_categoricals': None, 'time_varying_unknown_reals': ['cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std'], 'variable_groups': None, 'constant_fill_strategy': None, 'allow_missing_timesteps': False, 'lags': None, 'add_relative_time_idx': False, 'add_target_scales': True, 'add_encoder_length': True, 'target_normalizer': GroupNormalizer(
#   		method='standard',
#   		groups=['participant_id'],
#   		center=True,
#   		scale_by_group=False,
#   		transformation=None,
#   		method_kwargs={}
#   	), 'categorical_encoders': {'__group_id__participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'clinical_site': NaNLabelEncoder(add_nan=False, warn=True), 'study_group': NaNLabelEncoder(add_nan=False, warn=True), 'sleep_stage': NaNLabelEncoder(add_nan=False, warn=True)}, 'scalers': {
': 171, '1222': 172, '1223': 173, '1224': 174, '1225': 175, '1226': 176, '1227': 177, '1228': 178, '1229': 179, '1230': 180, '1231': 181, '1232': 182, '1233': 183, '1234': 184, '1235': 185, '1236': 186, '1237': 187, '1238': 188, '1239': 189, '1241': 190, '1242': 191, '1243': 192, '1244': 193, '1245': 194, '1246': 195, '1247': 196, '1248': 197, '1249': 198, '1250': 199, '1251': 200, '1252': 201, '1253': 202, '1254': 203, '1255': 204, '1256': 205, '1257': 206, '1258': 207, '1259': 208, '1260': 209, '1261': 210, '1262': 211, '1263': 212, '1264': 213, '1266': 214, '1267': 215, '1268': 216, '1269': 217, '1270': 218, '1271': 219, '1272': 220, '1273': 221, '1274': 222, '1275': 223, '1276': 224, '1277': 225, '1278': 226, '1280': 227, '1281': 228, '1283': 229, '1284': 230, '1285': 231, '1286': 232, '1287': 233, '1289': 234, '1290': 235, '1291': 236, '1292': 237, '1293': 238, '1294': 239, '1295': 240, '1297': 241, '1298': 242, '1300': 243, '1302': 244, '1303': 245, '1304': 246, '1305': 247, '1306': 248, '1307': 249, '1308': 250, '1309': 251, '1310': 252, '1311': 253, '1312': 254, '1313': 255, '1314': 256, '1315': 257, '1316': 258, '1317': 259, '1318': 260, '1320': 261, '1321': 262, '1322': 263, '1323': 264, '1324': 265, '1325': 266, '1326': 267, '1327': 268, '1328': 269, '1329': 270, '1330': 271, '1331': 272, '1332': 273, '1333': 274, '1334': 275, '1335': 276, '1336': 277, '1337': 278, '1339': 279, '1340': 280, '1341': 281, '1344': 282, '1345': 283, '1346': 284, '1347': 285, '1348': 286, '1349': 287, '1350': 288, '1351': 289, '1352': 290, '1353': 291, '1354': 292, '1355': 293, '1356': 294, '1357': 295, '1359': 296, '1361': 297, '1362': 298, '1363': 299, '1364': 300, '1365': 301, '1366': 302, '1367': 303, '1368': 304, '1372': 305, '1374': 306, '1376': 307, '1377': 308, '1379': 309, '1380': 310, '1381': ...
#   	"embedding_paddings":                []
#   	"embedding_sizes":                   {'participant_id': (741, 65), 'clinical_site': (3, 3), 'study_group': (4, 3), 'sleep_stage': (5, 4)}
#   	"hidden_size":                       64
#   	"initialization":                    lecun_normal
#   	"interpolation_mode":                linear
#   	"learning_rate":                     0.001
#   	"log_gradient_flow":                 False
#   	"log_interval":                      50
#   	"log_val_interval":                  50
#   	"monotone_constraints":              {}
#   	"n_blocks":                          [1, 1]
#   	"n_layers":                          [1, 1]
#   	"naive_level":                       True
#   	"optimizer":                         adam
#   	"optimizer_params":                  None
#   	"output_size":                       1
#   	"output_transformer":                GroupNormalizer(
#   		method='standard',
#   		groups=['participant_id'],
#   		center=True,
#   		scale_by_group=False,
#   		transformation=None,
#   		method_kwargs={}
#   	)
#   	"pooling_mode":                      max
#   	"pooling_sizes":                     [2, 2]
#   	"prediction_length":                 12
#   	"reduce_on_plateau_min_lr":          1e-05
#   	"reduce_on_plateau_patience":        4
#   	"reduce_on_plateau_reduction":       2.0
#   	"shared_weights":                    True
#   	"static_categoricals":               ['participant_id', 'clinical_site', 'study_group']
#   	"static_hidden_size":                32
#   	"static_reals":                      ['age', 'encoder_length', 'cgm_glucose_center', 'cgm_glucose_scale']
#   	"time_varying_categoricals_decoder": ['sleep_stage']
#   	"time_varying_categoricals_encoder": ['sleep_stage']
#   	"time_varying_reals_decoder":        ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag']
#   	"time_varying_reals_encoder":        ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag', 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   	"weight_decay":                      0.001
#   	"x_categoricals":                    ['participant_id', 'clinical_site', 'study_group', 'sleep_stage']
#   	"x_reals":                           ['age', 'encoder_length', 'cgm_glucose_center', 'cgm_glucose_scale', 'ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag', 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   (loss): MAE()
#   (logging_metrics): ModuleList(
#     (0): SMAPE()
#     (1): MAE()
#     (2): RMSE()
#     (3): MAPE()
#     (4): MASE()
#   )
#   (embeddings): MultiEmbedding(
#     (embeddings): ModuleDict(
#       (participant_id): Embedding(741, 65)
#       (clinical_site): Embedding(3, 3)
#       (study_group): Embedding(4, 3)
#       (sleep_stage): Embedding(5, 4)
#     )
#   )
#   (model): NHiTS(
#     (blocks): ModuleList(
#       (0-1): 2 x NHiTSBlock(
#         (pooling_layer): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#         (static_encoder): StaticFeaturesEncoder(
#           (encoder): Sequential(
#             (0): Dropout(p=0.5, inplace=False)
#             (1): Linear(in_features=75, out_features=32, bias=True)
#             (2): ReLU()
#           )
#         )
#         (layers): MLP(
#           (layers): Sequential(
#             (0): Linear(in_features=7556, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Dropout(p=0.1, inplace=False)
#             (3): Linear(in_features=64, out_features=64, bias=True)
#             (4): ReLU()
#             (5): Dropout(p=0.1, inplace=False)
#             (6): Linear(in_features=64, out_features=294, bias=True)
#           )
#         )
#         (basis): IdentityBasis()
#       )
#     )
#   )
# )

# %%
# Get global metrics:
raw_preds = model.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"]#[:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/NHITS_288v2.csv", index=False)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Shape of raw_preds: torch.Size([741, 12, 1])
#           Metric       Mean   Lower CI   Upper CI
# 0          SMAPE   6.769904   6.368118   7.171690
# 1            MAE   9.193850   8.573059   9.814642
# 2           RMSE  10.776200  10.082285  11.470115
# 3  Quantile_Loss   4.596925   4.286529   4.907321
# /tmp/ipykernel_2393/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %% [markdown]
# # TFT (Old Version)

# %%
# TFT older version

# Load Data
import os
import sys
import torch

# Fetch best ckpt from GCS (use your actual bucket/prefix)
BUCKET = "cgmproject2025"
GCS_PREFIX = "checkpoints_tft_288v2"   # <- change if your run used a different folder
best_ckpt_path = download_best_ckpt_by_filename("checkpoints", BUCKET, GCS_PREFIX,
                                                run_prefix="tft288-", metric_key="val_loss")

#from TFT_pytorch import log_memory, create_tft_dataloaders, TFT_train
from scripts.oldtft288 import create_tft_dataloaders, TFT_train, save_tft_to_gcs, load_tft_from_gcs, TemporalFusionTransformer

# Rebuild the training dataset (same context_length, horizon, etc.)
training, val_dataloader, train_dataloader, validation = create_tft_dataloaders(train, horizon=12, context_length=288, batchsize=32)

# Load model from the checkpoint
device = "cuda" if torch.cuda.is_available() else "cpu"
tft = TemporalFusionTransformer.load_from_checkpoint(best_ckpt_path, map_location=device).to(device)
tft.eval()
# Out:
# Downloaded best checkpoint: gs://cgmproject2025/checkpoints_tft_288v2/tft288-epoch=06-val_loss=4.63.ckpt -> checkpoints/tft288-epoch=06-val_loss=4.63.ckpt
# [2025-09-01 19:48:18.561567] Start of Dataloader Creation
# GPU Mem allocated: 0.04 GB | reserved: 0.07 GB
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# TemporalFusionTransformer(
#   	"attention_head_size":               2
#   	"categorical_groups":                {}
#   	"causal_attention":                  True
#   	"dataset_parameters":                {'time_idx': 'ds', 'target': 'cgm_glucose', 'group_ids': ['participant_id'], 'weight': None, 'max_encoder_length': 288, 'min_encoder_length': 288, 'min_prediction_idx': np.int64(11), 'min_prediction_length': 12, 'max_prediction_length': 12, 'static_categoricals': ['participant_id', 'clinical_site', 'study_group'], 'static_reals': ['age'], 'time_varying_known_categoricals': ['sleep_stage'], 'time_varying_known_reals': ['ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag'], 'time_varying_unknown_categoricals': None, 'time_varying_unknown_reals': ['cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std'], 'variable_groups': None, 'constant_fill_strategy': None, 'allow_missing_timesteps': False, 'lags': None, 'add_relative_time_idx': True, 'add_target_scales': True, 'add_encoder_length': True, 'target_normalizer': GroupNormalizer(
#   		method='standard',
#   		groups=['participant_id'],
#   		center=True,
#   		scale_by_group=False,
#   		transformation=None,
#   		method_kwargs={}
#   	), 'categorical_encoders': {'__group_id__participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'participant_id': NaNLabelEncoder(add_nan=False, warn=True), 'clinical_site': NaNLabelEncoder(add_nan=False, warn=True), 'study_group': NaNLabelEncoder(add_nan=False, warn=True), 'sleep_stage': NaNLabelEncoder(add_nan=False, warn=True)}, 'scalers': {
 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   	"weight_decay":                      0.0
#   	"x_categoricals":                    ['participant_id', 'clinical_site', 'study_group', 'sleep_stage']
#   	"x_reals":                           ['age', 'encoder_length', 'cgm_glucose_center', 'cgm_glucose_scale', 'ds', 'minute_of_day', 'tod_sin', 'tod_cos', 'activity_steps', 'calories_value', 'heartrate', 'oxygen_saturation', 'respiration_rate', 'stress_level', 'predmeal_flag', 'relative_time_idx', 'cgm_glucose', 'cgm_lag_1', 'cgm_lag_3', 'cgm_lag_6', 'cgm_diff_lag_1', 'cgm_diff_lag_3', 'cgm_diff_lag_6', 'cgm_lagdiff_1_3', 'cgm_lagdiff_3_6', 'cgm_rolling_mean', 'cgm_rolling_std']
#   (loss): QuantileLoss(quantiles=[0.1, 0.5, 0.9])
#   (logging_metrics): ModuleList(
#     (0): SMAPE()
#     (1): MAE()
#     (2): RMSE()
#     (3): MAPE()
#   )
#   (input_embeddings): MultiEmbedding(
#     (embeddings): ModuleDict(
#       (participant_id): Embedding(741, 64)
#       (clinical_site): Embedding(3, 3)
#       (study_group): Embedding(4, 3)
#       (sleep_stage): Embedding(5, 4)
#     )
#   )
#   (prescalers): ModuleDict(
#     (age): Linear(in_features=1, out_features=8, bias=True)
#     (encoder_length): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_glucose_center): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_glucose_scale): Linear(in_features=1, out_features=8, bias=True)
#     (ds): Linear(in_features=1, out_features=8, bias=True)
#     (minute_of_day): Linear(in_features=1, out_features=8, bias=True)
#     (tod_sin): Linear(in_features=1, out_features=8, bias=True)
#     (tod_cos): Linear(in_features=1, out_features=8, bias=True)
#     (activity_steps): Linear(in_features=1, out_features=8, bias=True)
#     (calories_value): Linear(in_features=1, out_features=8, bias=True)
#     (heartrate): Linear(in_features=1, out_features=8, bias=True)
#     (oxygen_saturation): Linear(in_features=1, out_features=8, bias=True)
#     (respiration_rate): Linear(in_features=1, out_features=8, bias=True)
#     (stress_level): Linear(in_features=1, out_features=8, bias=True)
#     (predmeal_flag): Linear(in_features=1, out_features=8, bias=True)
#     (relative_time_idx): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_glucose): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_lag_1): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_lag_3): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_lag_6): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_diff_lag_1): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_diff_lag_3): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_diff_lag_6): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_lagdiff_1_3): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_lagdiff_3_6): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_rolling_mean): Linear(in_features=1, out_features=8, bias=True)
#     (cgm_rolling_std): Linear(in_features=1, out_features=8, bias=True)
#   )
#   (static_variable_selection): VariableSelectionNetwork(
#     (flattened_grn): GatedResidualNetwork(
#       (resample_norm): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((7,), eps=1e-05, elementwise_affine=True)
#       )
#       (fc1): Linear(in_features=102, out_features=7, bias=True)
#       (elu): ELU(alpha=1.0)
#       (fc2): Linear(in_features=7, out_features=7, bias=True)
#       (gate_norm): GateAddNorm(
#         (glu): GatedLinearUnit(
#           (dropout): Dropout(p=0.2, inplace=False)
#           (fc): Linear(in_features=7, out_features=14, bias=True)
#         )
#         (add_norm): AddNorm(
#           (norm): LayerNorm((7,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (single_variable_grns): ModuleDict(
#       (participant_id): ResampleNorm(
#         (gate): Sigmoid()
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (clinical_site): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (study_group): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (age): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (encoder_length): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_glucose_center): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_glucose_scale): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (prescalers): ModuleDict(
#       (age): Linear(in_features=1, out_features=8, bias=True)
#       (encoder_length): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_glucose_center): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_glucose_scale): Linear(in_features=1, out_features=8, bias=True)
#     )
#     (softmax): Softmax(dim=-1)
#   )
#   (encoder_variable_selection): VariableSelectionNetwork(
#     (flattened_grn): GatedResidualNetwork(
#       (resample_norm): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#       )
#       (fc1): Linear(in_features=188, out_features=24, bias=True)
#       (elu): ELU(alpha=1.0)
#       (context): Linear(in_features=64, out_features=24, bias=False)
#       (fc2): Linear(in_features=24, out_features=24, bias=True)
#       (gate_norm): GateAddNorm(
#         (glu): GatedLinearUnit(
#           (dropout): Dropout(p=0.2, inplace=False)
#           (fc): Linear(in_features=24, out_features=48, bias=True)
#         )
#         (add_norm): AddNorm(
#           (norm): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (single_variable_grns): ModuleDict(
#       (sleep_stage): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (ds): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (minute_of_day): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (tod_sin): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (tod_cos): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (activity_steps): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (calories_value): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (heartrate): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (oxygen_saturation): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (respiration_rate): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (stress_level): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (predmeal_flag): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (relative_time_idx): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_glucose): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_lag_1): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_lag_3): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_lag_6): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_diff_lag_1): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_diff_lag_3): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_diff_lag_6): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_lagdiff_1_3): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_lagdiff_3_6): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_rolling_mean): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cgm_rolling_std): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (prescalers): ModuleDict(
#       (ds): Linear(in_features=1, out_features=8, bias=True)
#       (minute_of_day): Linear(in_features=1, out_features=8, bias=True)
#       (tod_sin): Linear(in_features=1, out_features=8, bias=True)
#       (tod_cos): Linear(in_features=1, out_features=8, bias=True)
#       (activity_steps): Linear(in_features=1, out_features=8, bias=True)
#       (calories_value): Linear(in_features=1, out_features=8, bias=True)
#       (heartrate): Linear(in_features=1, out_features=8, bias=True)
#       (oxygen_saturation): Linear(in_features=1, out_features=8, bias=True)
#       (respiration_rate): Linear(in_features=1, out_features=8, bias=True)
#       (stress_level): Linear(in_features=1, out_features=8, bias=True)
#       (predmeal_flag): Linear(in_features=1, out_features=8, bias=True)
#       (relative_time_idx): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_glucose): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_lag_1): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_lag_3): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_lag_6): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_diff_lag_1): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_diff_lag_3): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_diff_lag_6): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_lagdiff_1_3): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_lagdiff_3_6): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_rolling_mean): Linear(in_features=1, out_features=8, bias=True)
#       (cgm_rolling_std): Linear(in_features=1, out_features=8, bias=True)
#     )
#     (softmax): Softmax(dim=-1)
#   )
#   (decoder_variable_selection): VariableSelectionNetwork(
#     (flattened_grn): GatedResidualNetwork(
#       (resample_norm): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((13,), eps=1e-05, elementwise_affine=True)
#       )
#       (fc1): Linear(in_features=100, out_features=13, bias=True)
#       (elu): ELU(alpha=1.0)
#       (context): Linear(in_features=64, out_features=13, bias=False)
#       (fc2): Linear(in_features=13, out_features=13, bias=True)
#       (gate_norm): GateAddNorm(
#         (glu): GatedLinearUnit(
#           (dropout): Dropout(p=0.2, inplace=False)
#           (fc): Linear(in_features=13, out_features=26, bias=True)
#         )
#         (add_norm): AddNorm(
#           (norm): LayerNorm((13,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (single_variable_grns): ModuleDict(
#       (sleep_stage): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (ds): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (minute_of_day): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (tod_sin): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (tod_cos): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (activity_steps): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (calories_value): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (heartrate): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (oxygen_saturation): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (respiration_rate): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (stress_level): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (predmeal_flag): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (relative_time_idx): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.2, inplace=False)
#             (fc): Linear(in_features=8, out_features=128, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (prescalers): ModuleDict(
#       (ds): Linear(in_features=1, out_features=8, bias=True)
#       (minute_of_day): Linear(in_features=1, out_features=8, bias=True)
#       (tod_sin): Linear(in_features=1, out_features=8, bias=True)
#       (tod_cos): Linear(in_features=1, out_features=8, bias=True)
#       (activity_steps): Linear(in_features=1, out_features=8, bias=True)
#       (calories_value): Linear(in_features=1, out_features=8, bias=True)
#       (heartrate): Linear(in_features=1, out_features=8, bias=True)
#       (oxygen_saturation): Linear(in_features=1, out_features=8, bias=True)
#       (respiration_rate): Linear(in_features=1, out_features=8, bias=True)
#       (stress_level): Linear(in_features=1, out_features=8, bias=True)
#       (predmeal_flag): Linear(in_features=1, out_features=8, bias=True)
#       (relative_time_idx): Linear(in_features=1, out_features=8, bias=True)
#     )
#     (softmax): Softmax(dim=-1)
#   )
#   (static_context_variable_selection): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_initial_hidden_lstm): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_initial_cell_lstm): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_enrichment): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (lstm_encoder): LSTM(64, 64, batch_first=True)
#   (lstm_decoder): LSTM(64, 64, batch_first=True)
#   (post_lstm_gate_encoder): GatedLinearUnit(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc): Linear(in_features=64, out_features=128, bias=True)
#   )
#   (post_lstm_gate_decoder): GatedLinearUnit(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc): Linear(in_features=64, out_features=128, bias=True)
#   )
#   (post_lstm_add_norm_encoder): AddNorm(
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (post_lstm_add_norm_decoder): AddNorm(
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (static_enrichment): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (context): Linear(in_features=64, out_features=64, bias=False)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (multihead_attn): InterpretableMultiHeadAttention(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (v_layer): Linear(in_features=64, out_features=32, bias=True)
#     (q_layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=32, bias=True)
#     )
#     (k_layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=32, bias=True)
#     )
#     (attention): ScaledDotProductAttention(
#       (softmax): Softmax(dim=2)
#     )
#     (w_h): Linear(in_features=32, out_features=64, bias=False)
#   )
#   (post_attn_gate_norm): GateAddNorm(
#     (glu): GatedLinearUnit(
#       (dropout): Dropout(p=0.2, inplace=False)
#       (fc): Linear(in_features=64, out_features=128, bias=True)
#     )
#     (add_norm): AddNorm(
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (pos_wise_ff): GatedResidualNetwork(
#     (fc1): Linear(in_features=64, out_features=64, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (fc): Linear(in_features=64, out_features=128, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (pre_output_gate_norm): GateAddNorm(
#     (glu): GatedLinearUnit(
#       (fc): Linear(in_features=64, out_features=128, bias=True)
#     )
#     (add_norm): AddNorm(
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (output_layer): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
# Get the parameter count of tft
total_params = sum(p.numel() for p in tft.parameters())
print(f"Total parameters in TFT model: {total_params}")
# Out:
# Total parameters in TFT model: 332804

# %%
# Get global metrics:
raw_preds = tft.predict(val_dataloader, mode="raw", return_x=True, return_index=True)
print("Shape of raw_preds:", raw_preds.output["prediction"].shape)
y_pred = raw_preds.output["prediction"][:, :, 1] #To get median quantile.
y_true = raw_preds.x["decoder_target"]
index_df = raw_preds.index
records = []
for i in range(len(index_df)):
    uid = index_df.iloc[i]["participant_id"]
    time_start = index_df.iloc[i]["ds"]
    for t in range(y_pred.shape[1]):
        records.append({
            "participant_id": uid,
            "ds": int(time_start + t),
            "target": float(y_true[i, t]),
            "prediction": float(y_pred[i, t]),
        })
records = pd.DataFrame(records)

metricsCI = calculate_metrics_CI(records, train)
print(metricsCI)

# Save metrics locally
metricsCI.to_csv("./figures/TFT_288_330kparam.csv", index=False)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/shaksonisaac/miniconda3/envs/cgmall/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Shape of raw_preds: torch.Size([741, 12, 3])
#           Metric      Mean  Lower CI  Upper CI
# 0          SMAPE  5.402032  5.126947  5.677117
# 1            MAE  7.273744  6.853486  7.694001
# 2           RMSE  8.607033  8.122322  9.091744
# 3  Quantile_Loss  3.636872  3.426743  3.847001
# /tmp/ipykernel_2714/1184106390.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
